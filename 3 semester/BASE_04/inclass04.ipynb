# %%
# !pip install pandas
# !pip install openpyxl

# %%
import pandas as pd

# %%
# pd.DataFrame() - табличка целиком
# pd.Series() - часть таблички

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6]])

# %%
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df = pd.DataFrame({'col1': [1, 2, 3], 'col2': [4, 5, 6]})

# %%
df
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
df = pd.DataFrame([{'col1': 1, 'col2': 2}, {'col1': 3, 'col2': 4}])

# %%
df
# Out:
#    col1  col2
# 0     1     2
# 1     3     4

# %%
df = pd.DataFrame({'r1': {'c1': 1, 'c2': 2}, 'r2': {'c1': 3, 'c2': 4}})

# %%
df
# Out:
#     r1  r2
# c1   1   3
# c2   2   4

# %%
gicr = pd.read_excel('snippets.jahilkematiangmailcom_48122.xlsx')

# %%
gicr
# Out:
#     int_id                                                url  \
# 0        1  http://m.livejournal.com/read/user/nonalkohol/...
# 1        2    http://m.livejournal.com/read/user/savodka/2247
# 2        3    http://m.livejournal.com/read/user/f_l_y/315017
# 3        4  http://m.livejournal.com/read/user/sogomogo/89...
# 4        5  http://m.livejournal.com/read/user/sogomogo/89...
# ..     ...                                                ...
# 84      85  http://m.livejournal.com/read/user/dark_ffores...
# 85      86  http://m.livejournal.com/read/user/purple_gas_...
# 86      87   http://m.livejournal.com/read/user/shlang/105325
# 87      88  http://m.livejournal.com/read/user/arsenitim/2...
# 88      89  http://m.livejournal.com/read/user/haspar_arne...
#
#                                                  left   result  \
# 0                                        Вот зачетный  пепелац
# 1   полчаса по всему кампутеру = ) На этот раз мод...  пепелац
# ...

# %%
gicr.head()
# Out:
#    int_id                                                url  \
# 0       1  http://m.livejournal.com/read/user/nonalkohol/...
# 1       2    http://m.livejournal.com/read/user/savodka/2247
#
#                                                 left   result  \
# 0                                       Вот зачетный  пепелац
# 1  полчаса по всему кампутеру = ) На этот раз мод...  пепелац
#
#                                                right  center1  year  birth  \
# 0  !!! Не " тиббурон " каеша , но за такие деньги...  пепелац  2008      0
# 1  , который до сих верно мне служит и готов меня...  пепелац  2009      0
#
#    loc genrei      author source  corp_index  sub_query_index       id  \
# 0  NaN   blog  nonalkohol     lj          41            72852  6262132
# 1  NaN   blog     savodka     lj          41            72852  7507615
#
#    group_id compose_doc_id
# 0       NaN       38_10384
# 1       NaN       38_31055

# %%
gicr.tail()
# Out:
#     int_id                                                url  \
# 84      85  http://m.livejournal.com/read/user/dark_ffores...
# 85      86  http://m.livejournal.com/read/user/purple_gas_...
# 86      87   http://m.livejournal.com/read/user/shlang/105325
# 87      88  http://m.livejournal.com/read/user/arsenitim/2...
# 88      89  http://m.livejournal.com/read/user/haspar_arne...
#
#                                                  left   result  \
# 84  Здорово !!!!! Молодец , поздравляю . Теперь ос...  пепелац
# 85  конечно же . Нам в министерстве обороны дали г...  пепелац
# 86  Только выехали из жданович на трассу в минск ,...  пепелац
# 87  сдавал , а не мопед ... Зато выходишь утром - ...  пепелац
# 88  бейцим к асфальту прибивать ? На заднем плане ...  пепелац
#
#                                                 right  center1  year  birth  \
# 84                       , чтоб навыки не терялись :)  пепелац  2006      0
# ...

# %%
gicr.index
# Out:
# RangeIndex(start=0, stop=89, step=1)

# %%
df.index
# Out:
# Index(['c1', 'c2'], dtype='object')

# %%
# int32, float32, float64...

# %%
gicr.columns
# Out:
# Index(['int_id', 'url', 'left', 'result', 'right', 'center1', 'year', 'birth',
#        'loc', 'genrei', 'author', 'source', 'corp_index', 'sub_query_index',
#        'id', 'group_id', 'compose_doc_id'],
#       dtype='object')

# %%
for column in gicr.columns:
    print(gicr[column])

# %%
gicr.sample()
# Out:
#     int_id                                                url  \
# 74      75  http://m.livejournal.com/read/user/ladomata/19...
#
#                                                  left   result  \
# 74  Отбой , друзья . Кажется я вполне нормально во...  пепелац
#
#                                                 right  center1  year  birth  \
# 74  . Не всегда плавно меняю скорость и все еще на...  пепелац  2009      0
#
#     loc genrei    author source  corp_index  sub_query_index        id  \
# 74  NaN   blog  ladomata     lj          41            72852  23030352
#
#     group_id compose_doc_id
# 74       NaN      40_548189

# %%
pd.read_excel(path)
pd.read_csv(path, sep='\t')
pd.read_json(path)

df.to_excel(path)  # 'mytable.xlsx
df.to_csv(path)
df.to_json(path)

# %%
gicr.loc[0, 'url']
# Out:
# 'http://m.livejournal.com/read/user/nonalkohol/11481'

# %%
df.loc['c1']
# Out:
# r1    1
# r2    3
# Name: c1, dtype: int64

# %%
gicr.iloc[0, 1]
# Out:
# 'http://m.livejournal.com/read/user/nonalkohol/11481'

# %%
gicr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   int_id           89 non-null     int64
#  1   url              89 non-null     object
#  2   left             86 non-null     object
#  3   result           89 non-null     object
#  4   right            89 non-null     object
#  5   center1          89 non-null     object
#  6   year             89 non-null     int64
#  7   birth            89 non-null     int64
#  8   loc              62 non-null     object
#  9   genrei           89 non-null     object
#  10  author           89 non-null     object
#  11  source           89 non-null     object
#  12  corp_index       89 non-null     int64
#  13  sub_query_index  89 non-null     int64
#  14  id               89 non-null     int64
#  15  group_id         0 non-null      float64
#  16  compose_doc_id   89 non-null     object
# ...

# %%
gicr.describe()
# Out:
#           int_id         year        birth  corp_index  sub_query_index  \
# count  89.000000    89.000000    89.000000        89.0             89.0
# mean   45.000000  2009.595506   755.831461        41.0          72852.0
# std    25.836021     2.574875   966.806954         0.0              0.0
# min     1.000000  2003.000000     0.000000        41.0          72852.0
# 25%    23.000000  2007.000000     0.000000        41.0          72852.0
# 50%    45.000000  2010.000000     0.000000        41.0          72852.0
# 75%    67.000000  2012.000000  1980.000000        41.0          72852.0
# max    89.000000  2013.000000  1988.000000        41.0          72852.0
#
#                  id  group_id
# count  8.900000e+01       0.0
# mean   1.928899e+07       NaN
# std    1.413792e+07       NaN
# min    7.417300e+04       NaN
# 25%    5.129275e+06       NaN
# 50%    2.062453e+07       NaN
# 75%    3.152935e+07       NaN
# max    4.680299e+07       NaN

# %%
gicr['year'] == gicr.year

# %%
gicr[(gicr.year > 2010) & (gicr.birth > 1980)].head()
# Out:
#     int_id                                                url  \
# 25      26  http://m.livejournal.com/read/user/sasha_pasec...
# 43      44  http://m.livejournal.com/read/user/covetor/194...
# 62      63  http://m.livejournal.com/read/user/allve_bpb/6...
# 64      65  http://m.livejournal.com/read/user/lorinser55/...
# 82      83  http://m.livejournal.com/read/user/m_isachenko...
#
#                                                  left   result  \
# 25  кого мне искать . Второй момент - это постанов...  Пепелац
# 43  Cessna-162 со " стеклянной кабиной " . Я доучи...  пепелац
# 62  конечно не истеричка , но нервный слегка - чег...  пепелац
# 64  сейчас все никакие . Я позвоню ! Перезвонил хо...  пепелац
# 82  правила в Москве . Скажем , остановился под за...  пепелац
#
#                                                 right  center1  year  birth  \
# 25  стоял у меня на временном учете , потом этот у...  Пепелац  2013   1987
# ...

# %%
len(gicr[(gicr['year'] >= 2010)])
# Out:
# 53

# %%
gicr.isna().any()
# Out:
# int_id             False
# url                False
# left                True
# result             False
# right              False
# center1            False
# year               False
# birth              False
# loc                 True
# genrei             False
# author             False
# source             False
# corp_index         False
# sub_query_index    False
# id                 False
# group_id            True
# compose_doc_id     False
# dtype: bool

# %%
gicr.isnull().any()
# Out:
# int_id             False
# url                False
# left                True
# result             False
# right              False
# center1            False
# year               False
# birth              False
# loc                 True
# genrei             False
# author             False
# source             False
# corp_index         False
# sub_query_index    False
# id                 False
# group_id            True
# compose_doc_id     False
# dtype: bool

# %%
gicr['year'].mean()
# Out:
# 2009.5955056179776

# %%
gicr['year'].sum()
# Out:
# 178854

# %%
set(gicr['year'])
# Out:
# {2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013}

# %%
len(gicr['year'].unique())
# Out:
# 11

# %%
gicr.drop_duplicates(keep='first')

# %%
gicr.dropna()  # inplace=True

# %%
gicr.drop('group_id', axis=1, inplace=True)

# %%
gicr.head()
# Out:
#    int_id                                                url  \
# 0       1  http://m.livejournal.com/read/user/nonalkohol/...
# 1       2    http://m.livejournal.com/read/user/savodka/2247
# 2       3    http://m.livejournal.com/read/user/f_l_y/315017
# 3       4  http://m.livejournal.com/read/user/sogomogo/89...
# 4       5  http://m.livejournal.com/read/user/sogomogo/89...
#
#                                                 left   result  \
# 0                                       Вот зачетный  пепелац
# 1  полчаса по всему кампутеру = ) На этот раз мод...  пепелац
# 2  сам позвонить - есть шанс заработать половину ...  пепелац
# 3  Когда сойдет снежный пиздец на дорогах , отдам...  Пепелац
# 4  за диск , да ? а тачка потому же и зовется Ско...  Пепелац
#
#                                                right  center1  year  birth  \
# 0  !!! Не " тиббурон " каеша , но за такие деньги...  пепелац  2008      0
# ...

# %%
df
# Out:
#     r1  r2
# c1   6   3
# c2   2   4

# %%
df.loc['c1', 'r1'] = 6

# %%
# df.iterrows()

# %%
gicr['birth'] = gicr['birth'].apply(lambda x: None if x == 0 else x)  #apply(myfunc)

def myfunc(x):
    if x == 0:
        return None
    return x

# %%
gicr.head()
# Out:
#    int_id                                                url  \
# 0       1  http://m.livejournal.com/read/user/nonalkohol/...
# 1       2    http://m.livejournal.com/read/user/savodka/2247
# 2       3    http://m.livejournal.com/read/user/f_l_y/315017
# 3       4  http://m.livejournal.com/read/user/sogomogo/89...
# 4       5  http://m.livejournal.com/read/user/sogomogo/89...
#
#                                                 left   result  \
# 0                                       Вот зачетный  пепелац
# 1  полчаса по всему кампутеру = ) На этот раз мод...  пепелац
# 2  сам позвонить - есть шанс заработать половину ...  пепелац
# 3  Когда сойдет снежный пиздец на дорогах , отдам...  Пепелац
# 4  за диск , да ? а тачка потому же и зовется Ско...  Пепелац
#
#                                                right  center1  year   birth  \
# 0  !!! Не " тиббурон " каеша , но за такие деньги...  пепелац  2008     NaN
# ...

# %%
gicr.describe()
# Out:
#           int_id         year        birth  corp_index  sub_query_index  \
# count  89.000000    89.000000    34.000000        89.0             89.0
# mean   45.000000  2009.595506  1978.500000        41.0          72852.0
# std    25.836021     2.574875    14.863521         0.0              0.0
# min     1.000000  2003.000000  1901.000000        41.0          72852.0
# 25%    23.000000  2007.000000  1976.000000        41.0          72852.0
# 50%    45.000000  2010.000000  1982.000000        41.0          72852.0
# 75%    67.000000  2012.000000  1985.500000        41.0          72852.0
# max    89.000000  2013.000000  1988.000000        41.0          72852.0
#
#                  id
# count  8.900000e+01
# mean   1.928899e+07
# std    1.413792e+07
# min    7.417300e+04
# 25%    5.129275e+06
# 50%    2.062453e+07
# 75%    3.152935e+07
# max    4.680299e+07

# %%
gicr.groupby('year').mean()
# Out:
#          int_id        birth  corp_index  sub_query_index            id
# year
# 2003  45.500000          NaN        41.0          72852.0  2.515148e+07
# 2004  58.000000  1979.000000        41.0          72852.0  6.657895e+06
# 2005  60.000000  1974.000000        41.0          72852.0  2.720149e+07
# 2006  66.375000  1982.500000        41.0          72852.0  2.890147e+07
# 2007  42.250000  1985.333333        41.0          72852.0  1.611174e+07
# 2008  39.833333  1983.750000        41.0          72852.0  2.844191e+06
# 2009  49.166667  1986.000000        41.0          72852.0  1.837320e+07
# 2010  43.000000  1979.200000        41.0          72852.0  1.612823e+07
# 2011  48.125000  1985.250000        41.0          72852.0  2.389033e+07
# 2012  29.200000  1975.500000        41.0          72852.0  1.911070e+07
# 2013  43.076923  1966.250000        41.0          72852.0  2.165791e+07

# %%
gicr.pivot_table(columns=['year', 'birth'], aggfunc='mean')
# Out:
# year                  2004        2005        2006                    2007  \
# birth               1979.0      1974.0      1981.0      1984.0      1983.0
# corp_index            41.0        41.0        41.0        41.0        41.0
# id               6657895.0  27201488.0  34077862.0  38755799.0  23982187.0
# int_id                58.0        60.0        61.0        87.0        63.5
# sub_query_index    72852.0     72852.0     72852.0     72852.0     72852.0
#
# year                                       2008                        ...  \
# birth               1986.0      1987.0   1982.0     1983.0     1988.0  ...
# corp_index            41.0        41.0     41.0       41.0       41.0  ...
# id               5129275.0  40312462.5  74173.0  5666856.0  2310248.0  ...
# int_id                29.5        49.5     39.5       81.0       35.0  ...
# sub_query_index    72852.0     72852.0  72852.0    72852.0    72852.0  ...
#
# ...
