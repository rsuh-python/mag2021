# %% [markdown]
# ## Задание 1.
#
# В файле 01-1.txt есть некоторые строчки, в которых есть знак @. Перезапишите в выходной файл только те строчки, в которых нет этого знака.

# %%
# your code here

# %% [markdown]
# ## Задание 2.
#
# Считайте текст из файла 01-2.txt, разделите его на слова и отсортируйте по алфавиту. Считывать нужно по строчке (наш файл маленький, а если бы он был большим?)

# %%
# your code here

# %% [markdown]
# ## Задание 3.
#
# Запишите любой текстовый файл в папку с путем /myfolder/myfile. Не создавайте эти папки руками в проводнике, программа должна сама их завести.

# %%
# your code here

# %% [markdown]
# ## Задание 4.
#
# В папке data содержатся файлы с англоязычными текстами. Программе передается только путь к этой папке, но не названия файлов (файлы в теории могут добавляться, мы заранее не знаем ни их названий, ни их числа). Во всех файлах есть только стандартные символы пунктуации, цифры и латинские буквы (диакритик нет). Подсчитайте статистику по каждому файлу: у вас должна быть функция, которая считает количество символов в файле, количество слов (достаточно использовать split() и strip()) и количество строк. Статистику запишите в отдельный файл.

# %%
# your code here

# %% [markdown]
# Задания на повторение:

# %% [markdown]
# ## Задание 5.
#
# Пользователь вводит целое число. Мы должны посчитать сумму его цифр (н-р, для 1234 сумма будет равна 10)

# %%
# your code here

# %% [markdown]
# ## Задание 6.
#
# Вводится год (н-р, 2012). Программа должна вывести, является ли он високосным (високосный год - такой, который делится на 4, но при этом не делится на 100 и на 400).

# %%
# your code here

# %% [markdown]
# ## Задание 7.
#
# Яша плавал в бассейне размером N × M метров и устал. В этот момент он обнаружил, что находится на расстоянии x метров от одного из длинных бортиков (не обязательно от ближайшего) и y метров от одного из коротких бортиков. Какое минимальное расстояние должен проплыть Яша, чтобы выбраться из бассейна на бортик? Программа получает на вход числа N, M, x, y. Программа должна вывести число метров, которое нужно проплыть Яше до бортика.
#
# Продвинутые студенты решают без условных инструкций.

# %%
# your code here

# %% [markdown]
# ## Задание 8.
#
# Вводится натуральное число N. Напечатайте все N-значные натуральные нечетные числа в порядке убывания. Условными инструкциями пользоваться запрещено.

# %%
# your code here

# %% [markdown]
# ## \* Задание 9.
#
# Дано натуральное число n. Выведите в порядке возрастания все четырёхзначные числа, сумма цифр которых равна n. Подумайте про оптимальность: представьте, что вам нужно написать высокоэффективный код, который будет вызываться миллионы раз в секунду для разных чисел, время исполнения которого критически важно. Приниматься будут только те решения, которые нельзя улучшить на порядок по количеству выполняемых операций (и, соответственно, времени).

# %%
# your code here

# %% [markdown]
# ## Задание 10.
#
# Сначала с экрана водится натуральное число X. Далее пользователь вводит последовательность чисел: числа вводятся последовательно по одному, последовательность завершается числом 0. Если в последовательности в какой-то момент встречается число X, программа должна прервать процесс и напечатать, каким по счёту в последовательности было это число. Если же число X не встретилось и последовательность закончилась, следует напечатать: "Число X не встретилось" (вместо 'X' должно быть его значение).

# %%
# your code here

# %% [markdown]
# ## Задание 11.
#
# Последовательность вводится с экрана и состоит из слов русского языка и завершается пустой строкой. Выведите длины и индексы всех слов, состоящих из нечётного количества букв в формате:
#
#     <слово1> (<длина1>) - <индекс1>
#     <слово2> (<длина2>) - <индекс2>
#     ...
#
# Например, если на 7-ом месте встретилось слово 'я', надо вывести:
#
#     'я (7) - 1'
#
# Если таких слов нет, выведите на экран "Все слова чётной длины". Также требуется вывести на экран, сколько встретилось слов чётной длины.

# %%
# your code here

# %% [markdown]
# ## Задание 12.
#
# Даны два целых числа A и B. Выведите все числа от A до B включительно в порядке возрастания, если A < B, и в порядке убывания, если B < A. Цикл должен быть только один.

# %%
# your code here

# %% [markdown]
# ## Задание 13.
#
# Вводится строка из слов русского языка (могут быть простые символы пунктуации). Посчитайте среднее количество слогов для этих слов.

# %%
# your code here

# %% [markdown]
# ## Задание 14.
#
# Вводится количество точек на плоскости, а затем в цикле запрашиваются координаты (x, y) для каждой следующей точки. Сделайте из введенных значений список пар координат в кортежах. Выведите True, если все точки лежат на одной прямой, и False, если нет. Точки лежат на одной прямой, если расстояние по х между двумя соседними точками постоянно и расстояние по y тоже постоянно (но может отличаться от расстояния по х). Пример точек, лежащих на одной прямой:
#
#     [(1, 2), (4, 3), (7, 4)]

# %%
# your code here

# %% [markdown]
# # Задание 15 (развлекательное)
#
# Пользователь вводит общий вопрос на русском языке (на который можно ответить да/нет). Программа, конечно, может гадать рандомом, но интереснее хоть как-то привязать ответ к самому вопросу; давайте это сделаем при помощи количества букв в словах. Таким образом, в первую строчку записываем числа: <количество слов в вопросе> <длина 1 слова> <длина 2 слова> ... После чего складываем числа по парам: первое со вторым, второе с третьим и так далее, чтобы получилась строчка на 1 элемент короче. Если результат сложения >= 10, вычитаем столько девяток, чтобы получилось однозначное число (9 годится, 10 - нет). Таким же образом обрабатываем вторую получившуюся строку и делаем так, пока не останется одно-единственное число. Если оно четное, ответ "да", если нечетное - ответ "нет". Таким образом, ответ на "получу ли я зачет по программированию" должен быть "да". Если очень хочется, можно отлавливать слова регуляркой, но необязательно (предположим, что знаки препинания в вопросе отсутствуют)

# %%
# your code here
