# %% [markdown]
# ### Общие задачи

# %% [markdown]
# #### Задание 1.
#
# У вас есть коллекция текстовых файлов, которые рассортированы по папкам внутри одной большой папки (например, общая папка Fiction, а внутри папки с фамилиями писателей, и у каждого писателя по два-три файла). Кроме текстовых файлов, могут попадаться файлы .jpg (с фотографиями писателей или обложками книг). Сами текстовые файлы тоже называются по-разному: некоторые начинаются с двух цифр (01, 02...) - они относятся к библиографии писателя, а другие с цифр не начинаются, в них содержится биография и подобное. Воспользуйтесь командой os.walk (почитайте о ней в документации), чтобы обойти все эти файлы и открыть только текстовые, причем только те, названия которых начинаются с цифр. Что вы с ними будете делать, на ваше усмотрение, можете просто названия файлов собрать, как самый простой вариант.

# %%
# your code here (optionally)

# %% [markdown]
# #### Задание 2.
#
# Создайте собственный модуль: соберите туда несколько функций, которые потенциально могут пригодиться (iscyrillic, например). Импортируйте этот модуль в другой скрипт и вызовите какую-нибудь его функцию.

# %% [markdown]
# ### Задачи для продвинутого трека

# %% [markdown]
# #### Задание 3.
#
# Что же, напишем игру - симулятор домашних питомцев. Сама игра протекает в цикле (графикой заморачиваться не станем), где человеку предлагаются разные действия: он может в самом начале завести животное, дать ему имя, выбрать возраст (ну и вид животного, конечно); потом можно выбирать опции типа "кормить животное", "играть с животным", в них может ничего особенно осмысленного не происходить (хотя я приветствую, если вы заморочитесь с модулем time, например, и добавите какие-нибудь атрибуты помимо возраста и имени), но животное должно по-разному реагировать в зависимости от своего вида. Кстати, в модуле time есть функция sleep, которую тоже можно приспособить, чтобы все не происходило мгновенно.

# %%
# your code here (optionally)

# %% [markdown]
# #### Задание 4.
#
# Соберем библиотеку полезных инструментов для операций над матрицами (вообразим себе, что numpy не существует...), а также для вычисления формул комбинаторики. Создайте два скрипта, в одном пусть будут все функции для матриц, которые мы (должны были) писать в прошлом семестре, а в другом реализуйте функции, которые вычисляют число комбинаций по формулам перестановки, размещений и т.п.. В вашей библиотеке должен быть файл \_\_init\_\_.py, в котором должно быть прописано, что импортировать при \*.
